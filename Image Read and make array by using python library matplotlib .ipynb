# %% [markdown]
# # Matplotlib Imshow - Read & Show Image Using Imread() &    " plt.imshow()" make array
#
#
# If you worry about, how to read and show an image using the matplotlib library then here you will get a solution for your problem. Along with that, you will be got a bonus. The matplotlib imshow() function helps to show the image.
# <br><br>
# But plt.imshow() didn’t work without mpimg.imread() function which is belongs to matplotlib.image module. So lets start practical.

# %%
# Import Libraries
import matplotlib.pyplot as plt
import matplotlib.image as mpimg # image module for image reading

# %% [markdown]
# ## Reading Image
# Here, we use "mpimg.imread()" method. <br>
# Which belongs to the matplotlib image module.

# %%
img = mpimg.imread('Anshu.jpg') # give addres of image location
print(img)
# Out:
# [[[212 210 211]
#   [210 208 209]
#   [211 209 210]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[213 211 212]
#   [210 208 209]
#   [209 207 208]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[216 214 215]
#   [210 208 209]
#   [209 207 208]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  ...
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [251 251 251]
#   [255 255 255]
#   [252 252 252]]
#
#  [[255 255 255]
#   [255 255 255]
#   [254 254 254]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [254 254 254]
#   [254 254 254]
#   ...
#   [255 255 255]
#   [254 254 254]
#   [255 255 255]]]

# %% [markdown]
# Above you can see, when we call img then got numpy array but how. <br>
# because<b><i> mpimg.imread() </b></i>function read <b>Anshu.jpg</b> image and store in <b><i>numpy array</b></i> format.

# %%
print('Data type of image : ',type(img))
print('Shape of image : ',img.shape)
print('Dimention of image : ',img.ndim)
# Out:
# Data type of image :  <class 'numpy.ndarray'>
# Shape of image :  (2096, 1916, 3)
# Dimention of image :  3

# %% [markdown]
# ## To show an image, use <i> plt.imshow()</i> function

# %%
plt.imshow(img)
plt.show()

# %% [markdown]
# ### Now, removing the axis and increase figure size and then show teh same image

# %%
plt.figure(figsize=(16,9))
plt.axis('on')
plt.imshow(img)
plt.show()

# %% [markdown]
# ### Now, it looks great but can we add it's a color bar.<br>Yes, using <i> "plt.colorbar()" </i> function

# %%
plt.figure(figsize=(16,9))
plt.axis("on")
plt.imshow(img)
plt.colorbar() # Show color bar of above image
plt.show()

# %% [markdown]
# Let’s play with plt.imshow() functions parameter. Here use cmap means color map to show a single-channel image in a different color.

# %%
single_channel = img[:,:,1] # get single channel data from img
plt.figure(figsize=(16,9))
plt.axis("on")
plt.imshow(single_channel, cmap = "nipy_spectral_r") # show image with hot color map
plt.colorbar()
plt.show()

# %%
img3 = mpimg.imread('selfie.jpg')
single_channel = img3[:,:,1] # get single channel data from img
plt.figure(figsize=(16,9))
plt.axis("on")
plt.imshow(single_channel, cmap = "RdYlGn") # show image with hot color map
plt.colorbar()
plt.show()

# %% [markdown]
# # color list

# %%
list=['Accent', 'Accent_r', 'Blues', 'Blues_r', 'BrBG', 'BrBG_r', 'BuGn', 'BuGn_r', 'BuPu', 'BuPu_r', 'CMRmap', 'CMRmap_r', 'Dark2', 'Dark2_r', 'GnBu', 'GnBu_r', 'Greens', 'Greens_r', 'Greys', 'Greys_r', 'OrRd', 'OrRd_r', 'Oranges', 'Oranges_r', 'PRGn', 'PRGn_r', 'Paired', 'Paired_r', 'Pastel1', 'Pastel1_r', 'Pastel2', 'Pastel2_r', 'PiYG', 'PiYG_r', 'PuBu', 'PuBuGn', 'PuBuGn_r', 'PuBu_r', 'PuOr', 'PuOr_r', 'PuRd', 'PuRd_r', 'Purples', 'Purples_r', 'RdBu', 'RdBu_r', 'RdGy', 'RdGy_r', 'RdPu', 'RdPu_r', 'RdYlBu', 'RdYlBu_r', 'RdYlGn', 'RdYlGn_r', 'Reds', 'Reds_r', 'Set1', 'Set1_r', 'Set2', 'Set2_r', 'Set3', 'Set3_r', 'Spectral', 'Spectral_r', 'Wistia', 'Wistia_r', 'YlGn', 'YlGnBu', 'YlGnBu_r', 'YlGn_r', 'YlOrBr', 'YlOrBr_r', 'YlOrRd', 'YlOrRd_r', 'afmhot', 'afmhot_r', 'autumn', 'autumn_r', 'binary', 'binary_r', 'bone', 'bone_r', 'brg', 'brg_r', 'bwr', 'bwr_r', 'cividis', 'cividis_r', 'cool', 'cool_r', 'coolwarm', 'coolwarm_r', 'copper', 'copper_r', 'cubehelix', 'cubehelix_r', 'flag', 'flag_r', 'gist_earth', 'gist_earth_r', 'gist_gray', 'gist_gray_r', 'gist_heat', 'gist_heat_r', 'gist_ncar', 'gist_ncar_r', 'gist_rainbow', 'gist_rainbow_r', 'gist_stern', 'gist_stern_r', 'gist_yarg', 'gist_yarg_r', 'gnuplot', 'gnuplot2', 'gnuplot2_r', 'gnuplot_r', 'gray', 'gray_r', 'hot', 'hot_r', 'hsv', 'hsv_r', 'inferno', 'inferno_r', 'jet', 'jet_r', 'magma', 'magma_r', 'nipy_spectral', 'nipy_spectral_r', 'ocean', 'ocean_r', 'pink', 'pink_r', 'plasma', 'plasma_r', 'prism', 'prism_r', 'rainbow', 'rainbow_r', 'seismic', 'seismic_r', 'spring', 'spring_r', 'summer', 'summer_r', 'tab10', 'tab10_r', 'tab20', 'tab20_r', 'tab20b', 'tab20b_r', 'tab20c', 'tab20c_r', 'terrain', 'terrain_r', 'turbo', 'turbo_r', 'twilight', 'twilight_r', 'twilight_shifted', 'twilight_shifted_r', 'viridis', 'viridis_r', 'winter', 'winter_r']
print(list)
# Out:
# ['Accent', 'Accent_r', 'Blues', 'Blues_r', 'BrBG', 'BrBG_r', 'BuGn', 'BuGn_r', 'BuPu', 'BuPu_r', 'CMRmap', 'CMRmap_r', 'Dark2', 'Dark2_r', 'GnBu', 'GnBu_r', 'Greens', 'Greens_r', 'Greys', 'Greys_r', 'OrRd', 'OrRd_r', 'Oranges', 'Oranges_r', 'PRGn', 'PRGn_r', 'Paired', 'Paired_r', 'Pastel1', 'Pastel1_r', 'Pastel2', 'Pastel2_r', 'PiYG', 'PiYG_r', 'PuBu', 'PuBuGn', 'PuBuGn_r', 'PuBu_r', 'PuOr', 'PuOr_r', 'PuRd', 'PuRd_r', 'Purples', 'Purples_r', 'RdBu', 'RdBu_r', 'RdGy', 'RdGy_r', 'RdPu', 'RdPu_r', 'RdYlBu', 'RdYlBu_r', 'RdYlGn', 'RdYlGn_r', 'Reds', 'Reds_r', 'Set1', 'Set1_r', 'Set2', 'Set2_r', 'Set3', 'Set3_r', 'Spectral', 'Spectral_r', 'Wistia', 'Wistia_r', 'YlGn', 'YlGnBu', 'YlGnBu_r', 'YlGn_r', 'YlOrBr', 'YlOrBr_r', 'YlOrRd', 'YlOrRd_r', 'afmhot', 'afmhot_r', 'autumn', 'autumn_r', 'binary', 'binary_r', 'bone', 'bone_r', 'brg', 'brg_r', 'bwr', 'bwr_r', 'cividis', 'cividis_r', 'cool', 'cool_r', 'coolwarm', 'coolwarm_r', 'copper', 'copper_r', 'cubehelix', 'cubehelix_r', 'flag', 'flag_r
# ...

# %% [markdown]
# ## random color selection

# %%
import random as r
color=r.choice((list))
single_channel = img[:,:,1] # get single channel data from img
plt.figure(figsize=(16,9))
plt.axis("on")
plt.imshow(single_channel, cmap = color) # show image with hot color map
plt.colorbar()
plt.show()
print('Color name : ',color)
# Out:
# Color name :  Set1

# %% [markdown]
# # Conclusion
# In the matplotlib imshow, we learn : -
# <ul>
#   <li>How to read</li>
#   <li>Show image</li>
#   <li>colorbar</li>
#   <li>make array of image</li>
# </ul>
# with a real-time example using the <b> mpimage.imread, plt.imshow() and plt.colorbar()</b> function.

# %% [markdown]
# ===================================______________________========================================

# %% [markdown]
# # Here are I am using OOPs concepte
# # I'll make arrary of image and read image

# %%
class Imshow:
    def __init__(self,img_address,color):
        self.img_address=img_address
        self.color=color
    def plot_Imshow(self):
        import matplotlib.pyplot as plt
        import matplotlib.image as mpimg
        img = mpimg.imread(self.img_address )
        single_channel = img[:,:,1] # get single channel data from img
        plt.figure(figsize=(16,9))
        plt.axis("on")
        plt.imshow(single_channel, cmap = self.color) # show image with hot color map
        plt.colorbar()
        plt.show()
        print('array of image : ',img)

# %%
#Imshow(image name , color name)
img=Imshow('bird.jpg','nipy_spectral')
img.plot_Imshow()
# Out:
# array of image :  [[[ 93  88  69]
#   [ 93  88  69]
#   [ 93  88  69]
#   ...
#   [136 122  77]
#   [136 122  77]
#   [136 122  77]]
#
#  [[ 93  88  69]
#   [ 93  88  69]
#   [ 93  88  69]
#   ...
#   [136 122  77]
#   [136 122  77]
#   [136 122  77]]
#
#  [[ 93  88  69]
#   [ 93  88  69]
#   [ 93  88  69]
#   ...
#   [136 122  77]
#   [136 122  77]
#   [136 122  77]]
#
#  ...
#
#  [[ 25  18  10]
#   [ 26  19  11]
#   [ 30  23  15]
#   ...
#   [ 21  17  14]
#   [ 21  17  14]
#   [ 28  24  21]]
#
#  [[ 22  15   7]
#   [ 23  16   8]
#   [ 27  20  12]
#   ...
#   [ 21  17  16]
#   [ 18  14  13]
#   [ 24  20  19]]
#
#  [[ 22  15   7]
#   [ 22  15   7]
#   [ 27  20  12]
#   ...
#   [ 22  18  17]
#   [ 16  12  11]
#   [ 22  18  17]]]
